# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %%
url = "https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
pagencontent = response.text

# %%
soup = BeautifulSoup(pagencontent)

# %%
pname = soup.find("div",attrs = {"class":"RG5Slk"})

# %%
pname
# Out:
# <div class="RG5Slk">IQOO Z10X 5G (Titanium, 128 GB)</div>

# %%
productname = []

for x in soup.find_all("div",attrs = {"class":"RG5Slk"}):
    productname.append(x.text if x else np.nan)

for name in productname:
    print(name)
# Out:
# IQOO Z10X 5G (Titanium, 128 GB)
# realme P4x 5G (Lake Green, 128 GB)
# Ai+ Pulse (Black, 64 GB)
# IQOO Z10 Lite 5G (Titanium Blue, 128 GB)
# Ai+ Pulse (Black, 128 GB)
# MOTOROLA g06 power (Pantone tapestry, 64 GB)
# IQOO Z10X 5G (Ultramarine, 128 GB)
# REDMI A4 (Sparkle Purple, 128 GB)
# IQOO Z10 Lite 5G (Cyber Green, 128 GB)
# MOTOROLA g06 power (Pantone Laurel Oak, 64 GB)
# IQOO Z10 Lite 5G (Cyber Green, 128 GB)
# MOTOROLA g06 power (Pantone Tendril, 64 GB)
# IQOO Z10R 5G (Aquamarine, 256 GB)
# Ai+ Pulse (Sparkle Red, 64 GB)
# Ai+ Pulse (Green, 128 GB)
# Ai+ Pulse (Blue, 64 GB)
# IQOO Z10 Lite 5G (Titanium Blue, 256 GB)
# IQOO Z10 5G (Stellar Black / Black, 128 GB)
# hmd 105 Dual Sim Keypad Phone with Built-in UPI App, Wireless FM Radio
# HOTLINE Amaze H310
# Nokia 105 Classic Single Sim Keypad Phone, Without Charger
# MOTOROLA g57 power 5G (Pantone Fluidity, 128 GB)
# LAVA A2 Smart
# IQOO Z10 Lite 5G (Cyber Green, 256 GB)

# %%
price = soup.find("div",attrs = {"class":"hZ3P6w DeU9vF"})

# %%
price
# Out:
# <div class="hZ3P6w DeU9vF">₹14,996</div>

# %%
price = []

for x in soup.find_all("div",attrs = {"class":"hZ3P6w DeU9vF"}):
    price.append(x.text if x else np.nan)

for name in price:
    print(name)
# Out:
# ₹14,996
# ₹16,499
# ₹6,999
# ₹12,122
# ₹7,499
# ₹7,999
# ₹14,968
# ₹10,374
# ₹12,029
# ₹7,999
# ₹13,100
# ₹7,999
# ₹22,772
# ₹6,999
# ₹7,499
# ₹6,999
# ₹15,299
# ₹21,577
# ₹1,009
# ₹491
# ₹994
# ₹13,999
# ₹1,198
# ₹16,182

# %%
discount = soup.find("div",attrs = {"class":"HQe8jr"})

# %%
discount
# Out:
# <div class="HQe8jr"><span>14% off</span></div>

# %%
discount = []

for x in soup.find_all("div",attrs = {"class":"HQe8jr"}):
    discount.append(x.text if x else np.nan)

for name in discount:
    print(name)
# Out:
# 14% off
# 8% off
# 12% off
# 13% off
# 25% off
# 20% off
# 14% off
# 13% off
# 14% off
# 20% off
# 12% off
# 20% off
# 8% off
# 12% off
# 25% off
# 12% off
# 10% off
# 17% off
# 32% off
# 50% off
# 20% off
# 22% off
# 22% off
# 4% off
# 13% off
# 8% off
# 50% off
# 12% off
# 14% off

# %%
orginalprice = soup.find("div",attrs = {"class":"kRYCnD gxR4EY"})

# %%
orginalprice
# Out:
# <div class="kRYCnD gxR4EY">₹<!-- -->17,499</div>

# %%
orginalprice = []

for x in soup.find_all("div",attrs = {"class":"kRYCnD gxR4EY"}):
    orginalprice.append(x.text if x else np.nan)

for name in orginalprice:
    print(name)
# Out:
# ₹17,499
# ₹17,999
# ₹7,999
# ₹13,999
# ₹9,999
# ₹9,999
# ₹17,499
# ₹11,999
# ₹13,999
# ₹9,999
# ₹14,999
# ₹9,999
# ₹24,999
# ₹7,999
# ₹9,999
# ₹7,999
# ₹16,999
# ₹25,999
# ₹1,499
# ₹999
# ₹1,249
# ₹17,999
# ₹1,549
# ₹16,999

# %%
ratings = soup.find("div",attrs = {"class":"MKiFS6"})

# %%
ratings
# Out:
# <div class="MKiFS6">4.4<img class="PZfbSE" src="..."/></div>

# %%
ratings = []

for x in soup.find_all("div",attrs = {"class":"MKiFS6"}):
    ratings.append(x.text if x else np.nan)

for name in ratings:
    print(name)
# Out:
# 4.4
# 4.4
# 4.3
# 4.2
# 4.1
# 4.3
# 4.4
# 4.3
# 4.2
# 4.3
# 4.3
# 4.3
# 4.4
# 4.3
# 4.1
# 4.3
# 4.3
# 4.4
# 3.8
# 3.4
# 3.9
# 4.4
# 4
# 4.3
# 4.3
# 5
# 5
# 4.4
# 4
# 4
# 3.4
# 5
# 1
# 4.3
# 4
# 1
# 4.4
# 4
# 5

# %%
features = soup.find("div",attrs = {"class":"CMXw7N"})

# %%
features
# Out:
# <div class="CMXw7N"><ul class="HwRTzP"><li class="DTBslk">6 GB RAM | 128 GB ROM</li><li class="DTBslk">17.02 cm (6.7 inch) Display</li><li class="DTBslk">50MP Rear Camera</li><li class="DTBslk">6500 mAh Battery</li><li class="DTBslk">1 Year Warranty on Handset and 6 Months Warranty on Accessories</li></ul></div>

# %%
features = []

for x in soup.find_all("div",attrs = {"class":"CMXw7N"}):
    features.append(x.text if x else np.nan)

for name in features:
    print(name)
# Out:
# 6 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Display50MP Rear Camera6500 mAh Battery1 Year Warranty on Handset and 6 Months Warranty on Accessories
# 6 GB RAM | 128 GB ROM17.07 cm (6.72 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera7000 mAh BatteryDimensity 7400 Ultra Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories
# 4 GB RAM | 64 GB ROM | Expandable Upto 1 TB17.13 cm (6.745 inch) HD+ Display50MP Rear Camera | 5MP Front Camera5000 mAh BatteryT615 Processor1 Year Warranty on Handset and 6 Months Warranty on the Inbox Accessories
# 4 GB RAM | 128 GB ROM17.12 cm (6.74 inch) Display50MP Rear Camera6000 mAh Battery1 Year Warranty
# 6 GB RAM | 128 GB ROM | Expandable Upto 1 TB17.13 cm (6.745 inch) HD+ Display50MP Rear Camera | 5MP Front Camera5000 mAh BatteryT615 Processor1 Year Warranty on Handset and 6 Months Warranty on the Inbox Accessories
# ...

# %%
for i in range(1,463):
 url = f"https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={i}"
 print(url)
# Out:
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8
# ...

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time

productname = [] 
price = []
ratings = []
features = []
pagenum = []
originalprice = []
Discount = []
Review = []

total_time = time.time()

for i in range(1,463): 
    start_time = time.time()
    URL = f"https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={i}"
    page = requests.get(URL)
    soup = BeautifulSoup(page.text, "html.parser")

    for x in soup.find_all('div', attrs={'class':'ZFwe0M row'}):
        pname = x.find("div",attrs = {"class":"RG5Slk"})
        cost = x.find("div",attrs = {"class":"hZ3P6w DeU9vF"})  
        rat = x.find("div",attrs = {"class":"MKiFS6"})
        specs = x.find("div",attrs = {"class":"CMXw7N"})
        op = x.find("div",attrs = {"class":"kRYCnD gxR4EY"})
        discount = x.find("div",attrs = {"class":"HQe8jr"})
        reviews = x.find('span', attrs={'class':'PvbNMB'})
        

        productname.append(pname.text if pname else np.nan)
        price.append(cost.text if cost else np.nan)
        ratings.append(rat.text if rat else np.nan)
        features.append(specs.text if specs else np.nan)
        originalprice.append(op.text if op else np.nan)
        Discount.append(discount.text if discount else np.nan)
        Review.append(reviews.text if reviews else np.nan)
        
        pagenum.append(i)

    print(f'Page {i} completed in {time.time()-start_time:.2f} seconds')

print("Total Time Completed in seconds", str(time.time()-total_time))
# Out:
# Page 1 completed in 1.13 seconds
# Page 2 completed in 1.01 seconds
# Page 3 completed in 0.90 seconds
# Page 4 completed in 1.14 seconds
# Page 5 completed in 1.13 seconds
# Page 6 completed in 1.23 seconds
# Page 7 completed in 1.34 seconds
# Page 8 completed in 1.22 seconds
# Page 9 completed in 1.52 seconds
# Page 10 completed in 1.05 seconds
# Page 11 completed in 1.41 seconds
# Page 12 completed in 1.45 seconds
# Page 13 completed in 0.92 seconds
# Page 14 completed in 0.95 seconds
# Page 15 completed in 0.93 seconds
# Page 16 completed in 0.98 seconds
# Page 17 completed in 0.95 seconds
# Page 18 completed in 1.16 seconds
# Page 19 completed in 1.02 seconds
# Page 20 completed in 0.97 seconds
# Page 21 completed in 0.91 seconds
# Page 22 completed in 1.16 seconds
# Page 23 completed in 0.94 seconds
# Page 24 completed in 0.90 seconds
# Page 25 completed in 1.14 seconds
# Page 26 completed in 1.56 seconds
# Page 27 completed in 1.19 seconds
# Page 28 completed in 1.44 seconds
# ...

# %%
response = requests.get("https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

# %%
response
# Out:
# <Response [200]>

# %%
df = pd.DataFrame({"product_name":productname,"price":price,"ratings":ratings,"features":features,"pagenum":pagenum,"originalprice":originalprice,"Discount":Discount,"Review":Review})

# %%
df
# Out:
#                                       product_name    price ratings  \
# 0                  IQOO Z10X 5G (Titanium, 128 GB)  ₹14,996     4.4
# 1               realme P4x 5G (Lake Green, 128 GB)  ₹16,499     4.4
# 2                         Ai+ Pulse (Black, 64 GB)   ₹6,999     4.3
# 3         IQOO Z10 Lite 5G (Titanium Blue, 128 GB)  ₹12,122     4.2
# 4                        Ai+ Pulse (Black, 128 GB)   ₹7,499     4.1
# ..                                             ...      ...     ...
# 979                                 FONEME F24 PRO     ₹549     3.8
# 980                               ringme R1Pro 312     ₹599     3.3
# 981          realme 15 5G (Flowing Silver, 256 GB)  ₹32,999     4.4
# 982                          LAVA Hero Shakti 2025     ₹929     4.1
# 983  REDMI Note 14 Pro 5G (Champagne Gold, 256 GB)  ₹29,990     4.4
#
#                                               features  pagenum originalprice  \
# ...

# %%
df.to_csv("flipkart_mobiles_data.csv",index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.to_csv("flipkart_mobiles_data.csv",index = False)
#
# File E:\Anaconda\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File E:\Anaconda\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
# ...
